# %% [markdown]
# <h1> Task #4 </h1>`

# %% [markdown]
# Task is to create a Decision Tree classifier and visualize it graphically for the given Iris dataset.
# The purpose is if we feed any new data to this
# classifier, it would be able to predict the right class accordingly.

# %% [markdown]
# Decision trees are a popular supervised learning method for a variety of reasons. Benefits of decision trees include that they can be used for both regression and classification, they are easy to interpret and they don’t require feature scaling.

# %%
import pandas as pd #library for data analysis
import numpy as np #library for matrix manipulation
# sklearn library for machine learning algorithm

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn import metrics
import matplotlib.pyplot as plt  #libary for comprehensive 2D/3D plotting
import seaborn as sns
from sklearn import tree
from sklearn.metrics import accuracy_score,confusion_matrix

# %matplotlib inline

# %%
# Load data set 
from sklearn.datasets import load_iris
dat = load_iris()
data = pd.DataFrame(dat.data,columns = dat.feature_names)
y = dat.target

# %%
# Explore the data
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Shape of target data
y.shape
# Out:
# (150,)

# %%
# Check the column names
data.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
#Check null values
data.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
# Plot histogram of the given data 
data.hist(figsize = (12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x013BA5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x013EF8E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x01406CE8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0141CA00>]],
#       dtype=object)

# %%
# Pairplot of the given data
sns.pairplot(data)

# %%
# Build the model 
x = data
y = y
from sklearn .model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 42)

print("Shape of feature training data :",x_train.shape)
print("Shape of target training data :",y_train.shape)
print("Shape of feature test data :",x_test.shape)
print("Shape of target test data :",y_test.shape)
# Out:
# Shape of feature training data : (105, 4)
# Shape of target training data : (105,)
# Shape of feature test data : (45, 4)
# Shape of target test data : (45,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 42)

print("Shape of feature training data :",x_train.shape)
print("Shape of target training data :",y_train.shape)
print("Shape of feature test data :",x_test.shape)
print("Shape of target test data :",y_test.shape)


clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# Shape of feature training data : (105, 4)
# Shape of target training data : (105,)
# Shape of feature test data : (45, 4)
# Shape of target test data : (45,)
# DecisionTreeClassifier()

# %%
# Accuracy For training data
predict = clf.predict(x_train)
print("Accuracy of training data : ",accuracy_score(predict,y_train)*100,"%")
print("Confusin matrix of training data :'\n' ",confusion_matrix(predict,y_train))
sns.heatmap(confusion_matrix(predict,y_train),annot = True,cmap = 'BuGn')
# Out:
# Accuracy of training data :  100.0 %
# Confusin matrix of training data :'
# '  [[31  0  0]
#  [ 0 37  0]
#  [ 0  0 37]]

# %%
# Accuracy For testing data
predict = clf.predict(x_test)
print("Accuracy of testing data : ",accuracy_score(predict,y_test)*100,"%")
print("Confusin matrix of testing data :\n ",confusion_matrix(predict,y_test))
sns.heatmap(confusion_matrix(predict,y_test),annot = True,cmap = 'BuGn')
# Out:
# Accuracy of testing data :  100.0 %
# Confusin matrix of testing data :
#   [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
plt.figure(figsize  = (19,19))
tree.plot_tree(clf,filled = True,rounded = True,proportion = True,node_ids = True , feature_names = dat.feature_names)
plt.show()

# %% [markdown]
# **You can now feed any new/test data to this classifer and it would be able to predict the right class accordingly.**
